# %%
# %config InlineBackend.figure_format ='retina'
# %matplotlib inline

import networkx as nx
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# Set options
sns.set_style('darkgrid')
pd.set_option("display.max_rows", 10)

def read_excel(filespec):
    # read file into pandas DataFrame
    answer = pd.read_excel(filespec)
    
    # set column names to lower case for easier typing
    answer.columns = [colname.lower() for colname in list(answer.columns.values)]
    
    # return answer
    return(answer)

# %%
institutions = read_excel("data/HD2016.xlsx")
institutions = institutions.query("cyactive == 1 & iclevel == 1 & ugoffer == 1 & dfrcuscg in [1, 2]")
institutions = institutions[["unitid", "instnm", "city", "stabbr", "longitud", "latitude", "dfrcuscg"]]
institutions
# Out:
#       unitid                                         instnm            city  \
# 0     100654                       Alabama A & M University          Normal
# 1     100663            University of Alabama at Birmingham      Birmingham
# 2     100690                             Amridge University      Montgomery
# 3     100706            University of Alabama in Huntsville      Huntsville
# 4     100724                       Alabama State University      Montgomery
# ...      ...                                            ...             ...
# 7454  489344  Chamberlain College of Nursing-North Carolina       Charlotte
# 7455  489353      Chamberlain College of Nursing-California  Rancho Cordova
# 7497  489779                 Kaplan University-Indianapolis    Indianapolis
# 7498  489788                    Kaplan University-Milwaukee       Milwaukee
# 7512  489937              Piedmont International University   Winston-Salem
#
#      stabbr    longitud   latitude  dfrcuscg
# 0        AL  -86.568502  34.783368         1
# 1        AL  -86.799345  33.505697         1
# 2        AL  -86.174010  32.362609         2
# 3        AL  -86.640449  34.724557         2
# 4        AL  -86.295677  32.364317         1
# ...     ...         ...        ...       ...
# 7454     NC  -80.931971  35.137660         2
# 7455     CA -121.278258  38.596193         2
# 7497     IN  -86.109501  39.918440         2
# 7498     WI  -87.913354  43.038608         2
# 7512     NC  -80.250153  36.087962         2
#
# [2644 rows x 7 columns]

# %%
peer_lists = read_excel("data/CUSTOMCGIDS2016.xlsx")[["unitid", "cgunitid"]]
peer_lists
# Out:
#        unitid  cgunitid
# 0      100654    100706
# 1      100654    100724
# 2      100654    100830
# 3      100654    101480
# 4      100654    101879
# ...       ...       ...
# 43594  488679    465812
# 43595  488679    479956
# 43596  488679    480569
# 43597  488679    484631
# 43598  488679    489779
#
# [43599 rows x 2 columns]

# %%
peer_graph = nx.from_pandas_edgelist(peer_lists, "unitid", "cgunitid", create_using = nx.DiGraph)

peer_graph.number_of_nodes()
# Out:
# 4897

# %%
# nx.draw_networkx(peer_graph)
